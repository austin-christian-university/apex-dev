# %% [markdown]
# # Subcategory Aggregators (nbdev)
#
# Implement and test subcategory aggregation logic here. Export production code with `#| export` cells.

# %% [markdown]
# ## Subcategory Aggregation Method
#
# The method for doing the subcategory aggregation will proceed something like this:
#
# ### Pseudocode for Aggregator Loop
#
# ```python
# for student in students:
#     # Create a new JSON to store data for the student
#     student_data = {}
#
#     for subcategory in subcategories:
#         # Go fetch all the data for a given student
#         student_submissions = fetch_student_submissions(student.id, subcategory.id)
#
#         # Aggregate their data for the subcategory, with switches depending on the category
#         aggregated_score = aggregate_subcategory_data(student_submissions, subcategory)
#
#         student_data[subcategory] = aggregated_score
#
#     # Store JSON for the student in STUDENT_SUBCATEGORY_SCORES table
#     store_student_subcategory_scores(student.id, student_data)
# ```
#
# Then we loop through that until it's achieved for all students.
#
# **For testing purposes:**
# - Option to do single subcategories at a time
# - Option to do single students

# %%
#| default_exp aggregators
#| export
import logging
from datetime import datetime
from typing import Optional, Dict, Any, List
import os

import requests
from supabase import Client
from apex_scoring.bell_curve import BellCurveCalculator

logger = logging.getLogger(__name__)

from dotenv import load_dotenv
load_dotenv()

# Simple, env-configurable logging setup
# LOG_LEVEL: DEBUG|INFO|WARNING|ERROR, LOG_FORMAT: 'json' or 'plain'
LOG_LEVEL = (os.getenv('LOG_LEVEL') or 'INFO').upper()
LOG_FORMAT = (os.getenv('LOG_FORMAT') or 'plain').lower()

def setup_logging(level: str = LOG_LEVEL, fmt: str = LOG_FORMAT) -> None:
    level_value = getattr(logging, level, logging.INFO)
    handlers: list[logging.Handler] = []
    stream = logging.StreamHandler()
    if fmt == 'json':
        try:
            import json, time
            class JsonFormatter(logging.Formatter):
                def format(self, record: logging.LogRecord) -> str:
                    payload = {
                        'ts': int(time.time()),
                        'level': record.levelname,
                        'name': record.name,
                        'msg': record.getMessage(),
                    }
                    if record.exc_info:
                        payload['exc_info'] = self.formatException(record.exc_info)
                    return json.dumps(payload)
            stream.setFormatter(JsonFormatter())
        except Exception:
            stream.setFormatter(logging.Formatter('%(asctime)s [%(levelname)s] %(name)s: %(message)s'))
    else:
        stream.setFormatter(logging.Formatter('%(asctime)s [%(levelname)s] %(name)s: %(message)s'))
    handlers.append(stream)

    root = logging.getLogger()
    root.handlers.clear()
    root.setLevel(level_value)
    for h in handlers:
        root.addHandler(h)

# Initialize logging now for notebooks and for exported modules
setup_logging()

# Secondary logger for external calls
populi_logger = logging.getLogger('populi')


class PopuliClient:
    """Thin HTTP client for Populi API v2 using bearer auth.

    Requires `POPULI_URL` and `POPULI_API_KEY` in the environment.
    """
    def __init__(self, base_url: Optional[str] = None, api_key: Optional[str] = None):
        self.base_url = (base_url or os.getenv("POPULI_URL") or "").rstrip("/")
        self.api_key = api_key or os.getenv("POPULI_API_KEY")
        if not self.base_url or not self.api_key:
            raise RuntimeError("POPULI_URL and POPULI_API_KEY must be set for Populi access")

    def _request(self, endpoint: str, params: Optional[Dict[str, Any]] = None) -> Any:
        url = f"{self.base_url}/api2/{endpoint.lstrip('/')}"
        headers = {
            "Authorization": f"Bearer {self.api_key}",
            "Content-Type": "application/json",
        }
        populi_logger.debug(f"GET {url} params={params}")
        resp = requests.get(url, headers=headers, params=params or {}, timeout=30)
        populi_logger.debug(f"RESP {resp.status_code} for {url}")
        resp.raise_for_status()
        try:
            return resp.json()
        except Exception:
            return resp.text

    # Convenience wrappers matching server utils used in the web app
    def get_student(self, person_id: str) -> Any:
        return self._request(f"people/{person_id}/student")

    def get_enrollments(self, person_id: str, *, academic_term_id: Optional[str] = None, expand: Optional[str] = None) -> Any:
        params: Dict[str, Any] = {}
        if academic_term_id:
            params["academic_term_id"] = academic_term_id
        if expand:
            params["expand"] = expand
        return self._request(f"people/{person_id}/enrollments", params)

    def get_course_offering(self, course_offering_id: str) -> Any:
        return self._request(f"courseofferings/{course_offering_id}")

    def get_academic_terms(self) -> Any:
        return self._request("academicterms")

    


def _coerce_float(value: Any) -> Optional[float]:
    try:
        if value is None:
            return None
        if isinstance(value, (int, float)):
            return float(value)
        s = str(value).strip()
        if s == "":
            return None
        return float(s)
    except Exception:
        return None


def _letter_to_gpa_points(letter: Optional[str]) -> Optional[float]:
    if not letter or not isinstance(letter, str):
        return None
    l = letter.strip().upper()
    # Simple 4.0 scale mapping; adjust if Populi provides exact points
    mapping = {
        "A+": 4.0, "A": 4.0, "A-": 3.7,
        "B+": 3.3, "B": 3.0, "B-": 2.7,
        "C+": 2.3, "C": 2.0, "C-": 1.7,
        "D+": 1.3, "D": 1.0, "D-": 0.7,
        "F": 0.0,
    }
    return mapping.get(l)


def _percent_to_gpa(percent: Optional[float]) -> Optional[float]:
    p = _coerce_float(percent)
    if p is None:
        return None
    # Approximate conversion: 90+=4.0, 80+=3.0, 70+=2.0, 60+=1.0 else 0.0
    if p >= 90:
        return 4.0
    if p >= 80:
        return 3.0
    if p >= 70:
        return 2.0
    if p >= 60:
        return 1.0
    return 0.0


#This is the class that runs the whole process, then the cells below are for testing the class

class SubcategoryAggregator:
    GPA_SUBCATEGORY_IDS = {
        'f50830fe-b820-4223-89e2-e69241b459af',  # practicum grade
        '8d13f1b9-33e1-4a62-be45-488a6834112f',  # spiritual formation grade
        'd1d972a4-2484-4b9a-a53c-0b63bb2e952c',  # overall GPA
    }

    def __init__(self, supabase_client: Client):
        self.supabase = supabase_client
        self.bell_curve = BellCurveCalculator()
        logger.info("SubcategoryAggregator initialized")
    
    def get_students(self) -> list[dict]:
        resp = self.supabase.table('students').select('*').execute()
        return resp.data

    def get_single_student(self, student_id: str) -> dict:
        resp = self.supabase.table('students').select('*').eq('id', student_id).execute()
        return resp.data

    def get_subcategories(self) -> list[dict]:
        resp = self.supabase.table('subcategories').select('*').execute()
        return resp.data

    def get_single_subcategory(self, subcategory_id: str) -> dict:
        resp = self.supabase.table('subcategories').select('*').eq('id', subcategory_id).execute()
        return resp.data

    def get_student_submissions(self, student_id: str) -> list[dict]:
        resp = self.supabase.table('event_submissions').select('*').eq('student_id', student_id).eq('approval_stauts', 'approved').execute()
        return resp.data

    def get_student_submission_by_subcategory(self, student_id: str, subcategory_id: str) -> dict:
        resp = self.supabase.table('event_submissions').select('*').eq('student_id', student_id).eq('subcategory_id', subcategory_id).eq('approval_status', 'approved').execute()
        return resp.data

    def aggregate_subcategory_score(self, subcategory_name: str, subcategory_id: str, student_id: str) -> dict:
        logger.debug(f"aggregate_subcategory_score start subcategory={subcategory_name} sid={subcategory_id} student={student_id}")
  
        # 
        data_points_count = 0     
        
        #Route to appropriate function based on subcategory name
        if subcategory_name == 'fellow_friday_participation' or subcategory_name == 'gbe_participation' or subcategory_name == 'chapel_participation' or subcategory_name == 'company_team_building':
            student_subcategory_submissions = self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_involvement_scores(student_subcategory_submissions), data_points_count

        elif subcategory_name == 'practicum_grade' or subcategory_name == 'spiritual_formation_grade' or subcategory_name == 'class_attendance_grades':
            data_points_count = 1
            return self.aggregate_gpa(subcategory_name, student_id), data_points_count

        elif subcategory_name == 'credentials_certifications' or subcategory_name == 'job_promotion_opportunities':
            student_subcategory_submissions = self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_professional_development(student_subcategory_submissions), data_points_count

        elif subcategory_name == 'community_service_hours':
            student_subcategory_submissions = self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_service_hours(student_subcategory_submissions), data_points_count

        elif subcategory_name == 'lions_games_involvement':
            student_subcategory_submissions = self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_lions_games_scores(student_subcategory_submissions), data_points_count

        elif subcategory_name == 'small_group_involvement' or subcategory_name == 'dream_team_involvement':
            student_subcategory_submissions = self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_monthly_checkins(student_subcategory_submissions), data_points_count

        elif subcategory_name == 'fellow_friday_attendance' or subcategory_name == 'gbe_attendance' or subcategory_name == 'chapel_attendance' or subcategory_name == 'company_community_events':
            student_subcategory_submissions=self.get_student_submission_by_subcategory(student_id, subcategory_id)
            data_points_count = len(student_subcategory_submissions)
            return self.aggregate_attendance_percentage(student_subcategory_submissions), data_points_count

        #fallback to error
        else:
            raise ValueError(f"No match found for subcategory_name={subcategory_name}")

    def aggregate_attendance_percentage(self, student_subcategory_submissions: list[dict]) -> dict:
        #Get total occurences, then divide present count by total count. If no data, they were not present.

        #Get total occurences, then divide present count by total count. If no dat
        #Data structure is in event_submissions.submission_data
        # {"notes": "gbe_participation attendance #3", "status": "present", "submission_type": "attendance"}
        
        total_occurences = len(student_subcategory_submissions)
        present_count = sum(1 for submission in student_subcategory_submissions if submission['submission_data']['status'] == 'present')
        attendance_percentage = (present_count / total_occurences) * 100 if total_occurences > 0 else 0
        return attendance_percentage 


    def aggregate_monthly_checkins(self, student_subcategory_submissions: list[dict]) -> dict:

        #Data Structure:
        #{'notes': 'small_group monthly check #1', 'status': 'involved', 'submission_type': 'small_group'}
        #Alt type for status is 'not_involved'

        #Get total occurences, then divide present count by total count. If no data, they were not present.
        total_occurences = len(student_subcategory_submissions)
        present_count = sum(1 for submission in student_subcategory_submissions if submission['submission_data']['status'] == 'involved')
        monthly_checkin_percentage = (present_count / total_occurences) * 100 if total_occurences > 0 else 0
        return monthly_checkin_percentage


    def aggregate_involvement_scores(self, student_subcategory_submissions: list[dict]) -> dict:

        #Data Structure:
        # {'notes': 'gbe_participation attendance #1', 'points': 1, 'submission_type': 'participation'}

        print(f"Student subcategory submissions: {student_subcategory_submissions}")

        #Get total points
        total_points = sum(submission['submission_data']['points'] for submission in student_subcategory_submissions)
 
        return total_points
        
    def aggregate_service_hours(self, student_subcategory_submissions: list[dict]) -> dict:

        #Data Structure:
        #{'hours': 4, 'description': 'Magni culpo necessitatibus sulum timidus aeneus sit ancilla adstringo corporis.', 'organization': 'Community Garden', 'date_of_service': '2025-10-07', 'submission_type': 'community_service', 'supervisor_name': 'Trevor West', 'supervisor_contact': 'Chad.Zemlak@yahoo.com'}

        #Get total hours, then divide by 12. If no data, they did not meet the cap.
        total_hours = sum(submission['submission_data']['hours'] for submission in student_subcategory_submissions)
        capped_hours = min(total_hours, 12) if total_hours > 0 else 0
        return capped_hours

    def aggregate_professional_development(self, student_subcategory_submissions: list[dict]) -> dict:

        #Data Structure can be either of below, but we only care about the assigned_points for either
        #Job Promotion:
        # {'description': 'Aqua certus undique paens dolorum illo capio video abbas currus adnuo patruus.', 'organization': 'ACU Blueprintprintprintprintprintprintprintprintprintprint', 'assigned_points': 50, 'promotion_title': 'Assistant → Senior Assistant', 'submission_type': 'job_promotion', 'supervisor_name': 'Eugene Kunze', 'date_of_promotion': '2025-04-14', 'supervisor_contact': 'Fred.Hirthe@gmail.com'}
        # Credentials:
        # {'description': 'Synagoga provident audacia patior demergo alii ter aperiam unus desipio.', 'assigned_points': 33, 'credential_name': 'Google Analytics', 'submission_type': 'credentials', 'date_of_credential': '2025-06-14', 'granting_organization': 'Professional Certification Body'}

        #Get total points
        total_points = sum(submission['submission_data']['assigned_points'] for submission in student_subcategory_submissions)
        return total_points

    
    def aggregate_lions_games_scores(self, student_subcategory_submissions: list[dict]) -> dict:

        #Data Structure:
        # {'notes': 'lions games #1', 'assigned_points': 1, 'submission_type': 'lions_games'}

        #Get total points
        total_points = sum(submission['submission_data']['assigned_points'] for submission in student_subcategory_submissions)
        return total_points

    def aggregate_gpa(self, subcategory_name: str, student_uuid: str) -> dict:
        #So here we need to get the Populi API for either spiritual formation, practicum, or overall gpa

        #First, hit USERS table to get populi_id
        #Then, route to appropriate function based on subcategory name
        #Then figure out the populi API calls

        # Resolve Populi person id from our DB: students.student_id -> users.id -> users.populi_id
        # 1) Find student row by 6-digit student_uuid
        user_data = self.supabase.table('users').select('*').eq('id', student_uuid).limit(1).execute()
        if not user_data.data:
            raise ValueError(f"No user found for student_uuid={student_uuid}")
        user_id = user_data.data[0]['id']
        populi_id = user_data.data[0]['populi_id']

        #Then route to appropriate function based on subcategory name
        populi = PopuliClient()
        try:
            enrollments_payload = populi.get_enrollments(populi_id, expand='courseoffering')
        except Exception as e:
            logger.exception("Failed to fetch enrollments from Populi for populi_id=%s", populi_id)
            raise

        # Normalize payload to an array of enrollment rows
        if isinstance(enrollments_payload, dict) and 'data' in enrollments_payload:
            enrollments = enrollments_payload.get('data') or []
            if isinstance(enrollments, dict) and 'data' in enrollments:
                enrollments = enrollments.get('data') or []
        else:
            enrollments = enrollments_payload if isinstance(enrollments_payload, list) else []

        # Route by subcategory
        key = (subcategory_name or '').strip().lower()
        if key == 'practicum_grade':
            return self._compute_course_gpa(enrollments, include_keywords=['practicum'])
        if key == 'spiritual_formation_grade':
            return self._compute_course_gpa(enrollments, include_keywords=['spiritual', 'formation'])
        if key == 'class_attendance_grades':
            #This is not apply named at the moment as it only calculates the grades, will need to adjust Supabase subcategories and function logic in the future
            return self._compute_overall_gpa(enrollments)
            #return self._compute_attendance_percentage(enrollments)

        # Fallback: throw error because couldn't find a match
        raise ValueError(f"No match found for subcategory_name={subcategory_name}")

    def _extract_course_meta(self, enrollment: Dict[str, Any]) -> Dict[str, Any]:
        populi = PopuliClient()
        offering = populi.get_course_offering(enrollment['course_offering_id'])
        catalog_courses = offering.get('catalog_courses') or []
        catalog = catalog_courses[0] if isinstance(catalog_courses, list) and catalog_courses else {}
        return {
            'code': catalog.get('abbrv') or offering.get('abbrv'),
            'name': catalog.get('name') or offering.get('name'),
            'credits': enrollment.get('credits') or offering.get('credits'),
        }

    def _matches_keywords(self, text: Optional[str], keywords: list[str]) -> bool:
        if not text:
            return False
        t = text.lower()
        return all(k.lower() in t for k in keywords)

    def _enrollment_to_gpa(self, enrollment: Dict[str, Any]) -> Optional[float]:
        # Prefer letter grade if present
        letter = enrollment.get('letter_grade') or enrollment.get('letterGrade')
        points = _letter_to_gpa_points(letter)
        if points is not None:
            return points
        # Fallback to numeric percent
        percent = enrollment.get('final_grade') or enrollment.get('finalGrade')
        # print(f"Percent: {percent}")
        # print(f"Points: {_percent_to_gpa(percent)}")
        return _percent_to_gpa(percent)

    def _compute_course_gpa(self, enrollments: list[Dict[str, Any]], include_keywords: list[str]) -> float:
        matching: list[tuple[float, float]] = []  # (gpa_points, credits)
        for en in enrollments:
            meta = self._extract_course_meta(en)
            course_text = f"{meta.get('code') or ''} {meta.get('name') or ''}".strip()
            if not self._matches_keywords(course_text, include_keywords):
                continue
            gpa_points = self._enrollment_to_gpa(en)
            if gpa_points is None:
                continue
            credits = _coerce_float(meta.get('credits')) or 1.0
            matching.append((gpa_points, credits))

        if not matching:
            #If nothing matches, means they aren't in the class so we return None, not 0.0
            return None
        total_points = sum(g * c for g, c in matching)
        total_credits = sum(c for _, c in matching)
        #Here, None doesn't mean 0, it means they don't have a grade, so we need to return None
        return float(total_points / total_credits) if total_credits > 0 else None

    def _compute_overall_gpa(self, enrollments: list[Dict[str, Any]]) -> float:
        samples: list[tuple[float, float]] = []
        for en in enrollments:
            gpa_points = self._enrollment_to_gpa(en)
            if gpa_points is None:
                continue
            meta = self._extract_course_meta(en)
            credits = _coerce_float(meta.get('credits')) or 1.0
            samples.append((gpa_points, credits))
        if not samples:
            #If no courses, return None
            return None
        total_points = sum(g * c for g, c in samples)
        total_credits = sum(c for _, c in samples)
        return float(total_points / total_credits) if total_credits > 0 else 0.0

    def _compute_attendance_percentage(self, enrollments: list[Dict[str, Any]]) -> float:
        """Attempt to compute attendance percentage across enrollments.
        NOTE: This function is untested as it was not used in the first iteration of the app as of August 2025.
        Tries several shapes commonly seen in Populi payloads.
        Falls back to 0.0 if no attendance data is present.
        """
        total_present = 0
        total_meetings = 0
        for en in enrollments:
            # Common fields if provided
            percent = en.get('attendance_percentage') or en.get('attendancePercent')
            if percent is not None:
                p = _coerce_float(percent)
                if p is not None:
                    total_present += p
                    total_meetings += 100
                    continue
            attendance = en.get('attendance') or {}
            present = attendance.get('present') or attendance.get('present_count')
            meetings = attendance.get('meetings') or attendance.get('total_classes')
            if present is not None and meetings:
                try:
                    total_present += float(present)
                    total_meetings += float(meetings)
                except Exception:
                    pass
        if total_meetings <= 0:
            return None #If no meetings, need to not count this category so return is None, not 0.0
        return float((total_present / total_meetings) * 100.0)

    def _get_latest_scores_for_subcategory(self, subcategory_id: str) -> list[dict]:
        """Fetch latest-day rows for a subcategory from `student_subcategory_scores`.
        Returns rows with fields: id, student_id, score, calculation_date.
        """
        latest_resp = (
            self.supabase
            .table('student_subcategory_scores')
            .select('calculation_date')
            .eq('subcategory_id', subcategory_id)
            .order('calculation_date', desc=True)
            .limit(1)
            .execute()
        )
        if not latest_resp.data:
            return []
        latest_date = latest_resp.data[0]['calculation_date']

        rows_resp = (
            self.supabase
            .table('student_subcategory_scores')
            .select('id, student_id, score, calculation_date')
            .eq('subcategory_id', subcategory_id)
            .eq('calculation_date', latest_date)
            .execute()
        )
        return rows_resp.data or []


    def _normalize_latest_subcategory_scores(self, subcategory_id: str) -> dict:
        """Apply bell-curve normalization for the latest scores of a subcategory.
        For GPA subcategories, sets normalized_score = score (no bell curve).
        For non-GPA subcategories, applies bell curve normalization.
        Returns summary stats.
        """
        rows = self._get_latest_scores_for_subcategory(subcategory_id)
        if not rows:
            return {'normalized': False, 'reason': 'No rows to process', 'count': 0}

        if subcategory_id in getattr(self, 'GPA_SUBCATEGORY_IDS', set()):
            # GPA subcategories: set normalized_score = score (no bell curve)
            updated_count = 0
            for row in rows:
                if row.get('score') is not None:
                    self.supabase.table('student_subcategory_scores').update({
                        'normalized_score': float(row['score'])
                    }).eq('id', row['id']).execute()
                    updated_count += 1
            
            return {
                'normalized': False,
                'reason': 'GPA subcategory - normalized_score set to raw score',
                'count': updated_count,
            }

        # Non-GPA subcategories: apply bell curve normalization
        raw_scores: List[float] = [float(r['score']) for r in rows if r.get('score') is not None]
        if not raw_scores:
            return {'normalized': False, 'reason': 'No scores to normalize', 'count': 0}

        # Ensure bell curve calculator is available
        if not hasattr(self, 'bell_curve'):
            from apex_scoring.bell_curve import BellCurveCalculator
            self.bell_curve = BellCurveCalculator()

        normalized_scores, stats = self.bell_curve.apply_bell_curve_to_scores(raw_scores)

        # Write back normalized_score per row (same ordering)
        for row, norm in zip(rows, normalized_scores):
            self.supabase.table('student_subcategory_scores').update({
                'normalized_score': float(norm)
            }).eq('id', row['id']).execute()

        return {
            'normalized': True,
            'count': len(normalized_scores),
            'raw_stats': stats.get('raw_stats'),
            'normalized_stats': stats.get('normalized_stats'),
        }


    def normalize_all_subcategories_for_latest_day(self) -> dict:
        """Find all subcategories with rows on the latest day and normalize them.
        GPA subcategories get normalized_score = score, others get bell curve normalization."""
        latest_resp = (
            self.supabase
            .table('student_subcategory_scores')
            .select('calculation_date')
            .order('calculation_date', desc=True)
            .limit(1)
            .execute()
        )
        if not latest_resp.data:
            return {}
        latest_date = latest_resp.data[0]['calculation_date']

        sub_resp = (
            self.supabase
            .table('student_subcategory_scores')
            .select('subcategory_id')
            .eq('calculation_date', latest_date)
            .execute()
        )
        sub_ids = sorted({r['subcategory_id'] for r in (sub_resp.data or [])})

        results = {}
        for sid in sub_ids:
            # Process all subcategories (GPA ones will set normalized_score = score)
            results[sid] = self._normalize_latest_subcategory_scores(sid)
        return { 'latest_date': latest_date, 'results': results }

# %% [markdown]
# ## This cell below if for testing the full aggregator for a single student

# %%
from datetime import datetime

supabase_client = Client(os.getenv('SUPABASE_URL'), os.getenv('SUPABASE_SERVICE_ROLE_KEY'))

#Flow to test aggregator for single student

def test_aggregator_for_all_students():
    aggregator = SubcategoryAggregator(supabase_client)
    students = aggregator.get_students()
    for student in students:
        test_aggregator_for_single_student(student['id'])

def test_aggregator_for_single_student(student_id: str):
    student_subcategory_scores = {}
    aggregator = SubcategoryAggregator(supabase_client)
    student_submissions = aggregator.get_student_submissions(student_id)
    subcategories = aggregator.get_subcategories()
    for subcategory in subcategories:
        logger.info(f"Aggregating {subcategory['name']} for {student_id}")
        aggregate_subcategory_score, data_points_count = aggregator.aggregate_subcategory_score(subcategory['name'], subcategory['id'], student_id)

        #if aggregate_subcategory_score is None, skip entry
        if aggregate_subcategory_score is None:
            print(f"No score for {student_id} in {subcategory['name']}")
            continue

        resp = supabase_client.table('student_subcategory_scores').insert({
            'student_id': student_id,
            'subcategory_id': subcategory['id'],
            'score': aggregate_subcategory_score,
            'calculation_date': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            'data_points_count': data_points_count,
            'academic_year_start': 2025,
            'academic_year_end': 2026
        }).execute()
        logger.info(f"Raw score for {student_id} in {subcategory['name']} of {aggregate_subcategory_score} was added to the table")

        #Test prints
        # print(f"Aggregate subcategory score: {aggregate_subcategory_score}")

        # print(f"Subcategory name: {subcategory['name']}")
        # dummy_json = {
        #     'student_id': student_id,
        #     'subcategory_id': subcategory['id'],
        #     'score': aggregate_subcategory_score,
        #     'calculation_date': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        #     'data_points_count': data_points_count,
        #     'academic_year_start': 2025,
        #     'academic_year_end': 2026
        # }

        # print(f"Entry would be: {dummy_json}")

# Normalize a single subcategory (replace with an actual subcategory_id you want)
def test_normalize_single_subcategory(subcategory_id: str):
    aggregator = SubcategoryAggregator(supabase_client)
    result = aggregator._normalize_latest_subcategory_scores(subcategory_id)
    print('Single subcategory normalization result:')
    print(result)

# Normalize all non-GPA subcategories for the latest day
def test_normalize_all_latest_day():
    aggregator = SubcategoryAggregator(supabase_client)
    result = aggregator.normalize_all_subcategories_for_latest_day()
    print('All subcategories normalization for latest day:')
    print(result)

# test_aggregator_for_single_student('7630d221-e3aa-4126-a0e3-bee715160247')
# test_aggregator_for_all_students()
# test_normalize_single_subcategory('a3bab151-0ce1-402f-b507-7d6c3489bc8c') #Job promotion
test_normalize_all_latest_day()
# Out:
# 2025-08-12 14:51:38,087 [INFO] apex_scoring.bell_curve: Initialized BellCurveCalculator with mean=3.0, std_dev=0.6
# 2025-08-12 14:51:38,087 [INFO] __main__: SubcategoryAggregator initialized
# 2025-08-12 14:51:38,418 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:38,531 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=subcategory_id&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:38,628 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.0ceea111-1485-4a80-98a9-d82f3c12321c&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:38,736 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.0ceea111-1485-4a80-98a9-d82f3c12321c&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:38,740 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:38,740 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 13.32, Std: 6.72
# 2025-08-12 14:51:38,740 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.86, Std: 0.59
# 2025-08-12 14:51:38,740 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:38,852 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f82b0c44-3704-4841-9222-bdd5de6f2950 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:38,930 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d9cabbe2-800a-48cb-b8b6-9f09404c3e13 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,051 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.bc36914d-4fd6-40ee-82ea-6926d1b088aa "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,158 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.77c4b7ed-f8ba-4495-ae94-fab33acaad59 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,246 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.10b14b32-cbbd-45ed-8b5b-82a194ab24c8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,354 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.37c8f612-9ba6-4afc-9396-f6d06e8d1c4d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,449 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.7b35d145-1f87-48e8-93a9-5514b4057353 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,558 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.02c79e79-1c0c-4676-af53-33e30ee29eae "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,649 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3dcfe603-63b9-43b7-8386-2eda03a81bff "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,742 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.81dada7c-08a4-4b12-8e4c-96ec1cfa4c11 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,851 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.de15d208-8507-4f4f-9251-23c069d2bcde "HTTP/1.1 200 OK"
# 2025-08-12 14:51:39,942 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4a20f0f9-f12a-4286-897b-9bc04fa92989 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,037 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.cf05a72c-1f4b-4deb-a53e-89f64dc2cac3 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,142 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4627ce3c-9204-426e-805f-a6aa97697335 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,245 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.25cc5cb7-e2db-4540-b101-815b09b7d87f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,340 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a8152cb6-0ec1-45e6-80d6-d06fb0db5d12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,442 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b5646eb1-936d-4dbf-aab3-06f2cfd9caf0 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,545 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3e80adec-96ea-4a16-8b77-e66fded5ca78 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,623 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f94eacb9-ca9d-4dba-849a-84963f68982d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,724 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1eea5394-03eb-4638-aa55-98cd81b42316 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,808 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d1a33b56-4e87-420c-8a7e-e585ddde9689 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,901 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d5ebddda-f006-4d47-8133-3c18b5b6cf6c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:40,979 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.1a83ee45-7869-4f24-a70f-12ff3e1bc243&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,093 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.1a83ee45-7869-4f24-a70f-12ff3e1bc243&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,097 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:41,097 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 4.09, Std: 18.75
# 2025-08-12 14:51:41,097 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 1.27, Std: 0.55
# 2025-08-12 14:51:41,098 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:41,202 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.29c57606-3a76-4363-aefc-950af320a511 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,285 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e180966f-f54a-4f7f-8f13-0a96064eeb0d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,383 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.bea82138-ebc7-4a49-8c93-5874b6353a89 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,487 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.96243d5d-1d70-4aaa-bd7e-a85285607672 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,583 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.766f73d2-28da-431f-988c-0fc05fbe8d43 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,686 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4ae69ff9-f3b9-4347-9aca-2cdc530d8437 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,761 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.29bae138-8de2-4d44-87aa-c67e0dddeb29 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,850 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a5b97102-8677-4eba-8461-c03e46d9dbfe "HTTP/1.1 200 OK"
# 2025-08-12 14:51:41,939 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9a45b990-066f-4ed3-b5a1-7269d2b9b291 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,057 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.fbc3dacf-e1a5-4344-8f44-0ab55767ef38 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,156 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.2b05152a-6f65-4d6a-a220-77fc1a1bdb80 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,251 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5ef8679e-cd6d-4333-b8a5-c7ad2d7851a2 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,351 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.52786e9d-07ee-429a-9995-1fce01b58fda "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,456 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.25852e05-a9d2-44c6-9670-5ead229babd5 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,572 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.69c7f087-970e-46bf-89a9-0197b1bacde9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,683 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e86e2eaa-24d6-4a91-8089-f068b4bd8390 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,760 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e5bb15e3-5cc9-4d48-85a2-74a786082f41 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,860 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4ece5171-9952-4a78-9145-3a1917812f4a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:42,966 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.6673647d-a2c0-4e06-9218-a83d90fa1671 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,095 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.909ecc26-07e4-4638-9696-1dad39ef7503 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,204 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.950b16e5-b6dd-42fd-a8b6-8b1d2c7bea6c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,302 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d5b02547-b039-4d74-bc82-67c4377797b7 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,390 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.221c3ba8-42e5-4f4f-a553-ba3134b6d433&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,476 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.221c3ba8-42e5-4f4f-a553-ba3134b6d433&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,482 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:43,482 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 29.71, Std: 20.42
# 2025-08-12 14:51:43,483 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.65, Std: 0.87
# 2025-08-12 14:51:43,483 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:43,578 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e6fca791-8589-464f-b56b-e6c609b4b628 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,670 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.74a67007-b16e-438c-bc7d-6f43f4bcc5fa "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,774 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3ad85fe5-a594-4d7e-84c4-c56d691c8ed7 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,857 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9624f714-6f81-4cbe-b3d1-4b844085a067 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:43,967 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.7cf15117-4f4a-4e3b-ad9b-9d8c44e2c246 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,061 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.681e273e-3bbe-4a46-ab8e-966b43063d1c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,167 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.17f9bbca-66ba-4a99-ba49-3c744749fc2a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,253 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ad06e9a3-46ad-4055-8738-698c7a5c856d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,344 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3f7b4902-7991-47ce-b905-ccb3fe41dc91 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,436 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e05564d6-cde4-44d5-9b77-bd5551b9db7b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,531 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8d6789e9-34b8-4666-b16e-5c8ef304e500 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,614 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3a9aa233-3605-44d2-8d5b-1212eea1c608 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,746 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1c5b31cc-1314-440c-ba78-29dcddaf151f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,830 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.fd630241-bac9-414f-9b4e-0d1fd578293e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:44,912 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.370b0b30-0f0d-46f8-82d3-de0bd93785bc "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,008 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5c07bd40-61ef-4d63-8c7b-9c99249227d9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,106 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.be02304b-8a05-479d-a2f7-95a24771aa45 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,205 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5040f919-91fc-41a5-8409-26255089e7a8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,309 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.cdb2987a-3ccc-4385-b3a9-5f36442cf1f1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,392 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.907d56de-4a0a-40c1-9dfe-43666ac25c9b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,476 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e07f9922-a0d4-4628-82df-a6d51fce5ac9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,567 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.2936c554-6c70-4950-b629-58e41238440b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,672 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.296e0201-be1f-4a9b-bebb-e4288046431d&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,775 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.296e0201-be1f-4a9b-bebb-e4288046431d&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,778 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:45,778 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 32.60, Std: 19.02
# 2025-08-12 14:51:45,779 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.81, Std: 0.67
# 2025-08-12 14:51:45,779 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:45,882 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c7bbb7bb-3dbd-4fb4-936a-dae2f51b4e20 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:45,961 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.eda1d530-acb0-4fe5-bf1a-ea8289247c10 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,070 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.6cabd3d5-6723-4d7d-a60b-a2c6e9148e84 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,198 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.cfe1acee-5569-4fb4-822a-5ce00f0c3a30 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,320 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e023e543-7de9-4137-9d5a-07d8dca3e566 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,405 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.0ff95f18-a31b-4d9c-9035-5b9c8134004a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,499 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3f41e2e4-9000-46ff-9706-47d4052c5593 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,625 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d114c8b9-fdd6-4e8a-b98e-1cdc40ec6768 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,717 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.dfd9ac9e-7a02-467d-9664-904a4e87c33a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,803 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.90ae87e7-d24e-4870-a8bd-e966e09929b3 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,899 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.498ab2ed-a64a-4243-b0bd-ef492276e6c8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:46,987 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.14e971d4-282c-47d8-8067-8e419c4106b6 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,076 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4e8b1bc3-e43a-44ec-8168-07bb1bb09697 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,160 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.49538985-f10e-4406-a41d-4591a927f041 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,237 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3219e039-01fc-4c50-b1c9-23d12b8e7348 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,337 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b331ac67-1db7-44be-bc1d-6c67c07839f0 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,435 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b40f2a4a-3da0-4a8e-a045-013c0212cc5e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,527 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f96a31c2-e1a8-4d29-9503-1b28d12e7369 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,607 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.0b5aaba2-e03a-482f-a5c4-c7bedd7c392c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,694 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.521dedcd-019f-417e-b065-fc8a20776e6d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,790 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.0917181c-d8d5-4547-977d-ef585a8387a2 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:47,890 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4d337bdb-33d6-4acc-a734-4e98f8c5127a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,011 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.49ccaacd-d437-4421-809a-f957c8b4baf8&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,121 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.49ccaacd-d437-4421-809a-f957c8b4baf8&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,124 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:48,124 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 24.64, Std: 19.07
# 2025-08-12 14:51:48,124 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.85, Std: 0.61
# 2025-08-12 14:51:48,125 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:48,221 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.596ffcf9-0077-4a60-a1f7-3c4dc8b23304 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,321 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.40d59d20-9924-45e3-89a1-c65230e09f9c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,422 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1143b04c-67bc-449f-b156-a1ff81280cc8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,509 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.af55c686-c7be-425e-8581-86c4661c30a1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,598 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.de4fefff-f43a-4257-b771-8b6977952cbc "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,698 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9762f28f-d5dc-4660-9eaa-54ac06cfd3f6 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,790 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9ece4520-b29f-4b80-868f-275d23d0c867 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,876 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.18fd854b-0adf-40b0-9be2-be813c5f2dc5 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:48,967 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.88f8ff07-62ce-49e4-96e5-6cbb823e3b5c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,057 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f7f844f4-68e1-4b11-84ef-3a7160861660 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,142 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.50005f15-b2e8-4b08-8e5c-21a72e5478a2 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,218 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.109fc1a7-d51b-4ea4-9bda-96edb314233c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,310 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8b250d82-7618-4730-94c7-aaeced8d9af2 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,420 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.642d35cf-d4bd-4fd5-b967-6847ee0cf07d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,535 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.13669c7b-95a9-4227-a22a-1264c882de19 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,616 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d7b7bb8b-a741-47af-918e-ec9a549dbf92 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,707 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.197404c0-c6c1-4f1f-a19d-77d4543a2969 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,779 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b005907c-9085-4bf8-bcea-d82b6d1610be "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,867 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8f3f870a-e6c0-4aaf-b609-c7502ef57b1a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:49,946 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.416846d1-47ec-46e5-a514-40ac7474fc14 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,018 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.52b18875-4a1b-4000-a258-ea447f5e5d6a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,121 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.183844d6-989e-4f8a-8e95-1fb023dcad4e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,213 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.78606cf2-7866-4ed5-8384-1e464a0b5d66&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,312 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.78606cf2-7866-4ed5-8384-1e464a0b5d66&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,314 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:50,314 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 17.14, Std: 8.05
# 2025-08-12 14:51:50,315 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.85, Std: 0.61
# 2025-08-12 14:51:50,315 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:50,420 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5832b038-a793-44e1-8237-3ddb8ae7489f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,493 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5ef76462-049e-46f0-b627-2310a5ebe1fb "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,588 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.202290e2-572a-4149-bb3d-6256d4116742 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,700 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.409de4df-364e-4815-8518-5d7848b0e550 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,772 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e5e9d8cd-23c6-46ce-8569-c2246fcbf26d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,873 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.298a3ff0-3f42-4e38-bd5b-8368d4087851 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:50,960 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8b631808-84fd-430e-a852-bff4282ed4a8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,051 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4c99cf66-d6c4-4e0c-951c-511859c52f1e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,129 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.bb8adb53-7635-411c-a8c3-7c8df2eb7338 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,221 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8e82ced9-6ec3-4ddc-b090-44788ba9f747 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,317 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c6a4da2e-5940-45ee-98b3-39152dbe58c5 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,406 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.2dad33c7-36ac-42b7-94fd-448d7f6cdee8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,513 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.42817ca3-1bb5-4f54-b799-0945d2bafbb8 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,606 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.eeff6139-8e3a-4ffe-9cf0-36a16e35227b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,704 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f740f80c-afe4-4477-ac01-294cc3a86b48 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,782 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.60e48c8c-6305-4963-b84c-686423adde97 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,862 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a1fa072f-a075-403f-a85b-2b0c4857033c "HTTP/1.1 200 OK"
# 2025-08-12 14:51:51,945 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e3af35b6-ef36-4602-9cde-fb5b5bf85d4f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,043 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d567d83e-f2ef-4181-b68e-30bdedcdd425 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,126 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a6f943b5-0017-4f6f-b6de-412ff6bbe509 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,201 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.27fe2d85-a876-4837-ba7f-9191470fb903 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,296 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d8b21598-5ecd-4611-8594-f61c680123f5 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,402 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,494 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,499 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:52,500 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 16.23, Std: 10.44
# 2025-08-12 14:51:52,500 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.84, Std: 0.59
# 2025-08-12 14:51:52,501 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:52,591 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8456c6cc-0188-4893-838c-1c9cd5e79d5d "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,709 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.055ec550-a8a4-43f1-a9cd-6440331e041f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,809 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.fdb6f3db-386e-4f28-8592-4759f1540124 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,912 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9dfb9520-0f38-4495-8903-1f957aa89b58 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:52,992 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.78a6ab33-b8e5-4542-be47-d24b41c16a57 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,071 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.29c335c0-8b6f-4135-a2b1-180badb83439 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,173 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.334ab3dc-57ce-4970-83fb-105015458603 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,267 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1778dd93-27c4-4dc3-95c4-77cefecf62fc "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,370 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c32e9790-037d-4ba1-a268-de3bd7940682 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,467 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5a51794a-364d-4b6c-9a70-a300b14445d4 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,560 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.35ff7d73-9663-4619-9ddc-3caac2311ed4 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,644 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4c2f1f9d-46ca-44cb-9821-e16059b540ef "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,735 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.00a92175-73f2-45ca-971f-e0ee26ce5be4 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,831 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.da8598bb-a01d-49ac-b4aa-d74d5a35f4fe "HTTP/1.1 200 OK"
# 2025-08-12 14:51:53,928 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.6b9819b3-bb90-48e3-9005-2e311c9a6ce9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,023 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d0731a1e-47ac-4823-a83c-ba8c6ef9b7b6 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,136 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.75f073df-b7d5-4cff-93f1-8f80965293e0 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,241 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.00a3a280-482a-4a15-a6b6-92e57ba9cd3e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,346 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.96ccf5cc-edb4-4e44-b833-558555dffe2f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,428 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.6db0d5cb-1c8c-4547-98cb-cb759cc91132 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,540 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c02936fb-6135-4197-a3e4-df097f95e8ae "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,623 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.29292bc2-9cc8-4547-bfc8-90a96d7637eb "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,713 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.8d13f1b9-33e1-4a62-be45-488a6834112f&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,808 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.8d13f1b9-33e1-4a62-be45-488a6834112f&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:54,902 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.117ecde3-8b34-4989-8fc5-6fcab555052f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,013 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a9cfec2a-b087-41a9-a722-cbcbb0325cdd "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,089 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ec04eacb-408f-4965-b76b-8c1efcfc1d50 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,192 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.54a40634-8dbd-40a2-901c-0c8dcd2b4f47 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,272 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.846a9ee0-37a9-42c6-85f1-afe1ac11363e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,395 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3bd5a08e-c3b1-4487-93e5-5f7d9acd430f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,483 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b7570613-abba-46c7-8cdd-16a604b44ea0 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,577 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9e7bb4e3-e795-40f6-83bb-6d688e17db94 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,688 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.64446c59-8830-4fbe-8b90-3179a720b0ae "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,794 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.8f64e5fd-a793-445a-8c96-d7095e8910b9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:55,890 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.0faf5c5a-6b17-4cf7-ae75-174ee6680a9b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,003 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c27082e7-591f-413c-a6bb-1c93f11aa185 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,087 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.a32c3898-dbf1-4a92-a5db-811dfb6fcd0f&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,191 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.a32c3898-dbf1-4a92-a5db-811dfb6fcd0f&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,193 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:56,193 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 45.83, Std: 32.34
# 2025-08-12 14:51:56,193 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.64, Std: 0.76
# 2025-08-12 14:51:56,193 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:56,280 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3916fc46-cb97-460c-b131-d85f10b34b70 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,362 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.46b10631-587d-4885-a5df-a54046ae521a "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,442 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b8266917-775b-4472-8ed8-ec3d538c62de "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,538 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.39535cb6-a6d0-473c-b987-fd9b8f570b8b "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,645 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.85b17ed4-284f-433f-8924-2ada813f3ad4 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,727 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d3954d39-1770-4c1a-9299-0e8f2e4890f1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,811 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.31cf9737-afda-4353-8229-3a36da54af33 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,895 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.589ad800-71b1-4f5d-90f8-49557781ae23 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:56,990 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.46051791-e071-41cc-826e-e2bd30e0c7d5 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,084 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.0a6e2a33-206e-4782-a4f9-4a86ebdb0d68 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,186 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d3f235ec-c732-47a0-89a7-cc553e1224ef "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,288 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.23245064-1491-4dbe-87c4-d5a026db0ce9 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,391 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ac09400a-2408-4aab-8164-f9f75557cc98 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,488 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e03f8f65-3205-4e96-a681-aebba5832c21 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,564 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.682f9326-6187-4a71-8874-9723b34d134f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,655 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f002e247-b56b-4655-a1a0-799fdd6d505f "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,751 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c91d53b7-1718-4f4d-9fd7-35c78413b9d6 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,847 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f090e78b-0a62-453b-a05a-5c6a861796d4 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:57,935 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.2a30b9cd-8158-4499-a15e-27ef6fd2c456 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,028 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.7a3b534c-d59b-41ca-9214-42c8948fa288 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,110 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.5b8d5aac-cc95-4010-8b79-d0bb22791209 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,252 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c7064d52-21ac-49f9-b673-f40985aedcb2 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,332 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.a3bab151-0ce1-402f-b507-7d6c3489bc8c&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,422 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.a3bab151-0ce1-402f-b507-7d6c3489bc8c&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,424 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:51:58,425 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 126.82, Std: 68.58
# 2025-08-12 14:51:58,425 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.87, Std: 0.60
# 2025-08-12 14:51:58,425 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:51:58,531 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9984330c-5414-4cf1-887d-7cd90232af36 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,633 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4aca3ec9-3b1d-481d-8834-55ae1df7580e "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,724 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.146d4c6a-3bba-4ad6-b2fa-d1acfeef3b36 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,815 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1920dca9-8a90-439a-bd7e-2e795f2488ac "HTTP/1.1 200 OK"
# 2025-08-12 14:51:58,927 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a5f40ef8-8a6c-4bc4-9bb5-938e4e812765 "HTTP/1.1 200 OK"
# 2025-08-12 14:51:59,004 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.56e0b265-350c-47e1-a1f6-738c1177b7df "HTTP/1.1 200 OK"
# 2025-08-12 14:51:59,116 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.14f787ca-2059-4828-8eb7-d8862e424fec "HTTP/1.1 200 OK"
# 2025-08-12 14:51:59,225 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3ec9f6d6-db85-4abb-a2d3-aec95875d3b1 "HTTP/1.1 200 OK"
# ...
# 2025-08-12 14:52:10,636 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.186e9f06-c6c3-4bc0-8dca-053425b3ce79 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:10,719 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.396aae6e-2376-4c3b-a474-a0b4acd4754d "HTTP/1.1 200 OK"
# 2025-08-12 14:52:10,804 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1ff8963b-e395-40b6-8e78-3bd9e47a4884 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:10,878 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.925e72b7-9724-4fd0-b80c-07ac11c87539 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:10,957 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d089b1fd-647c-437a-9381-e84bf88ac4bb "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,043 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.83e879ef-ee3f-4c8e-98ea-5cec2e0cd895 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,132 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.77586b11-10cb-4ac7-8e11-caa134c49e21 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,235 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e5340f46-d5ee-4c32-abca-e14522c5edb0 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,323 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9e80bee2-23b1-485f-91f4-4a72bad63316 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,397 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.def4c749-4ad2-4b7e-ae54-cbc2b1301c5b "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,488 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.02b34c87-113e-4049-a881-b61d67333051 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,599 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.23b6cdb0-ab18-4f36-acd6-bdaa0b267620 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,689 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.43462a91-654d-4584-aea7-c3168177b0ec "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,799 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.00d6b5a7-b31d-4408-b5bc-f7c57eb8d3a8 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:11,933 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.dd05af5e-0fcb-4eca-b815-d59d2e782c58 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,010 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ed715fed-6e42-492e-b3e3-20b955674859 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,094 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.abd4a5fa-94ea-4e29-beed-61addb115896 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,174 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a3c0a444-48d7-4555-9a06-da654bb9eb7a "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,275 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.60efc379-da5a-477c-a9d2-27db3b0233c5 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,364 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.efdbc642-a52d-4872-ada5-2687fc03be73&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,473 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.efdbc642-a52d-4872-ada5-2687fc03be73&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,476 [INFO] apex_scoring.bell_curve: Bell curve transformation completed:
# 2025-08-12 14:52:12,477 [INFO] apex_scoring.bell_curve:   Raw scores - Mean: 112.77, Std: 64.40
# 2025-08-12 14:52:12,477 [INFO] apex_scoring.bell_curve:   Normalized scores - Mean: 2.86, Std: 0.60
# 2025-08-12 14:52:12,478 [INFO] apex_scoring.bell_curve:   Target mean: 3.0, Target std: 0.6
# 2025-08-12 14:52:12,574 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a6ad0c73-56ce-4a8b-8e8c-1526dbae0367 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,673 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.eee722b7-6f85-4925-b8c7-de90790a5e4b "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,759 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.34478518-adf0-481b-a72a-4dd9dd98ebd2 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,861 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.e02ba54a-f71e-4eb0-bba8-1ab9cc9ff7d2 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:12,966 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ff84b5c2-cd82-4cf6-a999-a3a4239ea94e "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,072 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9ab522b8-9f23-4cb4-94ed-773dff99ed77 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,155 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.701ba94a-bbf1-4cef-a7f4-3383435a176e "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,262 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.744478ec-c7b8-48b6-9421-750d0e35f114 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,360 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.6f6dcb6b-6dae-468e-ba86-2a74fbd41c80 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,476 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.d53dcb90-1ebc-4b1c-93cd-2ff0850defb9 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,584 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.769f299a-c793-4b8c-b10e-3cf0cecead14 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,677 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.55e09481-dee9-43a1-8f97-fcdf1a6ea67a "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,768 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1f2a6096-107e-41a8-a08b-aac93553d2d0 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,844 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.1daf2474-e969-4699-8a09-324365a2901e "HTTP/1.1 200 OK"
# 2025-08-12 14:52:13,936 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.81de8c79-79e3-4adf-8945-6758f88243a7 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,031 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.898cbf45-cdc2-459e-9397-9ca89837a7ea "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,132 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4d13aded-c5ad-4cb0-ae93-8c997de51bd2 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,212 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.38d75457-6de0-4182-a97b-073fa13e14ad "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,307 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.c448f6ca-3fc8-4ad1-b9b2-d858066d0f88 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,401 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.91c479e4-88e4-4758-9c76-93532848f6b8 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,481 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.ea020fc1-3eff-414a-a1bd-895064cc968c "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,591 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.db47d014-cf33-4c6a-842e-0ccdc568d643 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,685 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=calculation_date&subcategory_id=eq.f50830fe-b820-4223-89e2-e69241b459af&order=calculation_date.desc&limit=1 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,780 [INFO] httpx: HTTP Request: GET https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?select=id%2C%20student_id%2C%20score%2C%20calculation_date&subcategory_id=eq.f50830fe-b820-4223-89e2-e69241b459af&calculation_date=eq.2025-08-12 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:14,895 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.efb03b1f-6a33-4697-be97-ca92a3d075d7 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,017 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.9e189511-5349-401b-9d7a-c7e09d5199b4 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,129 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.4c0372cf-a5db-4729-a09d-bd072930c34e "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,218 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.11c33376-0b6c-4498-85c1-9e93db05b319 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,310 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.907a8fb9-e08b-4687-9052-58892b9aa3e6 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,388 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.b2724d72-a792-4968-b31a-14edf8595704 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,480 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.a0c27de8-533d-4646-8908-82a08d47b246 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,581 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.f20464a7-d77a-4b9f-863e-fc5cd5173297 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,659 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.3b0c83f3-4a3c-4822-9a44-841ec32eb443 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,762 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.2e326f0b-9444-4173-9490-bb4a1cde92a4 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,875 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.758e5055-837f-4876-bc6a-918490081846 "HTTP/1.1 200 OK"
# 2025-08-12 14:52:15,969 [INFO] httpx: HTTP Request: PATCH https://ibucbpftrdxujktphifw.supabase.co/rest/v1/student_subcategory_scores?id=eq.61a9c1c9-8b67-4723-9bad-5d512445c656 "HTTP/1.1 200 OK"
# All subcategories normalization for latest day:
# {'latest_date': '2025-08-12', 'results': {'0ceea111-1485-4a80-98a9-d82f3c12321c': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 13.318181818181818, 'std_dev': 6.717591313696542, 'min': 1.0, 'max': 27.0, 'percentiles': {'10th': 4.300000000000001, '25th': 9.25, '50th': 12.5, '75th': 17.0, '90th': 22.700000000000006}}, 'normalized_stats': {'count': 22, 'mean': 2.859090909090909, 'std_dev': 0.5907230476359159, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 2.214, '25th': 2.5725, '50th': 2.965, '75th': 3.23, '90th': 3.5130000000000003}}}, '1a83ee45-7869-4f24-a70f-12ff3e1bc243': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 4.090909090909091, 'std_dev': 18.74690057027389, 'min': 0.0, 'max': 90.0, 'percentiles': {'10th': 0.0, '25th': 0.0, '50th': 0.0, '75th': 0.0, '90th': 0.0}}, 'normalized_stats': {'count': 22, 'mean': 1.2709090909090905, 'std_dev': 0.5540750612992061, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 1.15, '25th': 1.15, '50th': 1.15, '75th': 1.15, '90th': 1.15}}}, '221c3ba8-42e5-4f4f-a553-ba3134b6d433': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 29.714999999999996, 'std_dev': 20.423054207973358, 'min': 0.0, 'max': 66.67, 'percentiles': {'10th': 0.0, '25th': 14.29, '50th': 30.95, '75th': 46.1125, '90th': 50.0}}, 'normalized_stats': {'count': 22, 'mean': 2.6459090909090905, 'std_dev': 0.8682671305061338, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 1.15, '25th': 2.55, '50th': 2.895, '75th': 3.275, '90th': 3.36}}}, '296e0201-be1f-4a9b-bebb-e4288046431d': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 32.602272727272734, 'std_dev': 19.01833324400867, 'min': 0.0, 'max': 66.67, 'percentiles': {'10th': 10.0, '25th': 22.22, '50th': 30.95, '75th': 44.44, '90th': 61.25000000000003}}, 'normalized_stats': {'count': 22, 'mean': 2.808181818181818, 'std_dev': 0.6747298204307501, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 2.2, '25th': 2.55, '50th': 2.965, '75th': 3.23, '90th': 3.5130000000000003}}}, '49ccaacd-d437-4421-809a-f957c8b4baf8': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 24.636363636363637, 'std_dev': 19.065784332972115, 'min': 2.0, 'max': 101.0, 'percentiles': {'10th': 7.5, '25th': 14.25, '50th': 23.0, '75th': 28.0, '90th': 35.500000000000014}}, 'normalized_stats': {'count': 22, 'mean': 2.846363636363636, 'std_dev': 0.6077644987578767, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 2.025, '25th': 2.4975, '50th': 2.9299999999999997, '75th': 3.23, '90th': 3.521}}}, '78606cf2-7866-4ed5-8384-1e464a0b5d66': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 17.136363636363637, 'std_dev': 8.046995229985225, 'min': 1.0, 'max': 33.0, 'percentiles': {'10th': 9.0, '25th': 12.0, '50th': 18.0, '75th': 22.5, '90th': 25.900000000000002}}, 'normalized_stats': {'count': 22, 'mean': 2.847272727272727, 'std_dev': 0.6122624349543244, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 2.2, '25th': 2.55, '50th': 2.93, '75th': 3.275, '90th': 3.521}}}, '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 16.227272727272727, 'std_dev': 10.435654869819308, 'min': 2.0, 'max': 36.0, 'percentiles': {'10th': 5.2, '25th': 8.0, '50th': 11.0, '75th': 27.0, '90th': 28.0}}, 'normalized_stats': {'count': 22, 'mean': 2.838181818181818, 'std_dev': 0.5902282791324076, 'min': 1.15, 'max': 3.81, 'percentiles': {'10th': 2.214, '25th': 2.45, '50th': 2.895, '75th': 3.23, '90th': 3.36}}}, '8d13f1b9-33e1-4a62-be45-488a6834112f': {'normalized': False, 'reason': 'GPA subcategory - normalized_score set to raw score', 'count': 12}, 'a32c3898-dbf1-4a92-a5db-811dfb6fcd0f': {'normalized': True, 'count': 22, 'raw_stats': {'count': 22, 'mean': 45.833181818181814, 'std_dev': 32.34030308318703, 'min': 0.0, 'max': 100.0, 'percentiles': {'10th': 0.0, '25th': 23.3325, '50th': 50.0, '75th': 50.0, '90th': 100.0}}, 'normalized_stats': {'count': 22, 'mean': 2.640454545454545 ...

# %%
#Get example return from a monthly checkin

student_id = '7630d221-e3aa-4126-a0e3-bee715160247'
small_group_subcategory_id = 'a32c3898-dbf1-4a92-a5db-811dfb6fcd0f'

supabase_client = Client(os.getenv('SUPABASE_URL'), os.getenv('SUPABASE_SERVICE_ROLE_KEY'))

small_group_involvement = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, small_group_subcategory_id)

print(small_group_involvement[0]['submission_data'])

print("Community service hours example")

community_service_subcategory_id = 'bc062d8d-6e16-4f0a-84ca-5fd9d7c10f8c'
service_hours = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, community_service_subcategory_id)

print(service_hours[0]['submission_data'])

print("Particpation points example")

gbe_subcategory_id = '0ceea111-1485-4a80-98a9-d82f3c12321c'

gbe_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, gbe_subcategory_id)

print(gbe_subcategory_submissions[0]['submission_data'])


print("Professional development categories")
job_promotion_subcategory_id = 'a3bab151-0ce1-402f-b507-7d6c3489bc8c'
credential_subcategory_id = 'efdbc642-a52d-4872-ada5-2687fc03be73'

job_promotion_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, job_promotion_subcategory_id)

print(job_promotion_subcategory_submissions[0]['submission_data'])

credential_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, credential_subcategory_id)

print(credential_subcategory_submissions[0]['submission_data'])


print("Lions Games example")

lions_games_subcategory_id = '49ccaacd-d437-4421-809a-f957c8b4baf8'

lions_games_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, lions_games_subcategory_id)

print(lions_games_subcategory_submissions[0]['submission_data'])
# Out:
# {'notes': 'small_group monthly check #1', 'status': 'not_involved', 'submission_type': 'small_group'}
# Community service hours example
# {'hours': 4, 'description': 'Magni culpo necessitatibus sulum timidus aeneus sit ancilla adstringo corporis.', 'organization': 'Community Garden', 'date_of_service': '2025-10-07', 'submission_type': 'community_service', 'supervisor_name': 'Trevor West', 'supervisor_contact': 'Chad.Zemlak@yahoo.com'}
# Particpation points example
# {'notes': 'gbe_participation attendance #1', 'points': 1, 'submission_type': 'participation'}
# Professional development categories
# {'description': 'Aqua certus undique paens dolorum illo capio video abbas currus adnuo patruus.', 'organization': 'ACU Apex', 'assigned_points': 50, 'promotion_title': 'Assistant → Senior Assistant', 'submission_type': 'job_promotion', 'supervisor_name': 'Eugene Kunze', 'date_of_promotion': '2025-04-14', 'supervisor_contact': 'Fred.Hirthe@gmail.com'}
# {'description': 'Synagoga provident audacia patior demergo alii ter aperiam unus desipio.', 'assigned_points': 33, 'credential_name': 'Google Analytics', 'submission_type': 'credentials', 'date_of_credential': '2025-06-14', 'granting_organization': 'Professional Certification Body'}
# Lions Games example
# {'notes': 'Lions Games points #1', 'assigned_points': 12, 'submission_type': 'lions_games'}

# %% [markdown]
# ## These are cells for testing individual functions/calls

# %%
#Test Populi client connection
populi = PopuliClient()
print(populi.get_academic_terms())

# Test academic terms endpoint
try:
    terms = populi.get_academic_terms()
    print(f"Academic terms response: {type(terms)}")
    if isinstance(terms, dict) and 'data' in terms:
        print(f"Found {len(terms['data'])} terms")
    print("Terms sample:", terms[:2] if isinstance(terms, list) else terms.get('data', [])[:2])
except Exception as e:
    print(f"Populi API test failed: {e}")
# Out:
# {'object': 'list', 'count': 17, 'results': 17, 'results_per_page': None, 'pages': 1, 'page': 1, 'offset': 0, 'has_more': False, 'data': [{'object': 'academic_term', 'id': 287327, 'academic_year_id': 74196, 'name': 'Spring 2026', 'display_name': '2025-2026: Spring 2026', 'start_date': '2026-01-13', 'end_date': '2026-05-08', 'grades_date': '2026-05-22', 'add_drop_time': '2026-01-27T06:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2024-12-16T20:52:09+00:00', 'added_by_id': 24547414, 'start_year': 2025, 'end_year': 2026}, {'object': 'academic_term', 'id': 287326, 'academic_year_id': 74196, 'name': 'Fall 2025', 'display_name': '2025-2026: Fall 2025', 'start_date': '2025-08-18', 'end_date': '2025-12-12', 'grades_date': '2025-12-26', 'add_drop_time': '2025-09-01T05:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2024-12-16T20:52:09+00:00', 'added_by_id': 24547414, 'start_year': 2025, 'end_year': 2026}, {'object': 'academic_term', 'id': 287328, 'academic_year_id': 74195, 'name': 'Summer 2025', 'display_name': '2024-2025: Summer 2025', 'start_date': '2025-05-13', 'end_date': '2025-08-22', 'grades_date': '2025-09-05', 'add_drop_time': '2025-05-27T05:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2025-05-14T14:01:57+00:00', 'added_by_id': 24547242, 'start_year': 2024, 'end_year': 2025}, {'object': 'academic_term', 'id': 287325, 'academic_year_id': 74195, 'name': 'Spring 2025', 'display_name': '2024-2025: Spring 2025', 'start_date': '2025-01-13', 'end_date': '2025-05-01', 'grades_date': '2025-05-15', 'add_drop_time': '2025-01-27T06:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2024-02-25T17:03:56+00:00', 'added_by_id': 24547242, 'start_year': 2024, 'end_year': 2025}, {'object': 'academic_term', 'id': 287324, 'academic_year_id': 74195, 'name': 'Fall 2024', 'display_name': '2024-2025: Fall 2024', 'start_date': '2024-08-19', 'end_date': '2024-12-12', 'grades_date': '2024-12-26', 'add_drop_time': '2024-09-02T05:00:00+00:00', 'enrollment_start_time': ...
# Academic terms response: <class 'dict'>
# Found 17 terms
# Terms sample: [{'object': 'academic_term', 'id': 287327, 'academic_year_id': 74196, 'name': 'Spring 2026', 'display_name': '2025-2026: Spring 2026', 'start_date': '2026-01-13', 'end_date': '2026-05-08', 'grades_date': '2026-05-22', 'add_drop_time': '2026-01-27T06:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2024-12-16T20:52:09+00:00', 'added_by_id': 24547414, 'start_year': 2025, 'end_year': 2026}, {'object': 'academic_term', 'id': 287326, 'academic_year_id': 74196, 'name': 'Fall 2025', 'display_name': '2025-2026: Fall 2025', 'start_date': '2025-08-18', 'end_date': '2025-12-12', 'grades_date': '2025-12-26', 'add_drop_time': '2025-09-01T05:00:00+00:00', 'enrollment_start_time': None, 'enrollment_end_time': None, 'max_enrolled_credits': None, 'max_enrolled_hours': None, 'max_audit_credits': None, 'max_audit_hours': None, 'non_standard': False, 'type': 'standard', 'evaluations_available_from': None, 'evaluations_available_to': None, 'evaluations_lock_grades_at': None, 'online_registration_delay_until': None, 'online_registration_randomization_seconds': 0, 'evaluations_lock_grades_until': None, 'evaluations_available_to_faculty': None, 'lms_sync': None, 'external_id': None, 'added_at': '2024-12-16T20:52:09+00:00', 'added_by_id': 24547414, 'start_year': 2025, 'end_year': 2026}]

# %%
# Test the student_id -> populi_id resolution logic
from supabase import Client
import os

supabase = Client(os.getenv('SUPABASE_URL'), os.getenv('SUPABASE_SERVICE_ROLE_KEY'))
aggregator = SubcategoryAggregator(supabase)

# Test with a known student_uuid 
test_student_id = '7630d221-e3aa-4126-a0e3-bee715160247'  # Replace with actual student_id from your DB

#Set up case with 1 = practicum, 2 = spiritual formation, 3 = overall

case = 3

if case == 1:
    practicum_gpa = aggregator.aggregate_gpa('practicum_grade', test_student_id)
    print(f"Practicum GPA: {practicum_gpa}")
elif case == 2:
    spiritual_gpa = aggregator.aggregate_gpa('spiritual_formation_grade', test_student_id)
    print(f"Spiritual Formation GPA: {spiritual_gpa}")
elif case == 3:
    overall_gpa = aggregator.aggregate_gpa('class_attendance_grades', test_student_id)
    print(f"Overall GPA: {overall_gpa}")
else:
    print("Invalid case")
# Out:
# Aggregating GPA for class_attendance_grades
# Overall GPA: 4.0

# %%
#Get example data structures for subcategories

student_id = '7630d221-e3aa-4126-a0e3-bee715160247'
small_group_subcategory_id = 'a32c3898-dbf1-4a92-a5db-811dfb6fcd0f'

supabase_client = Client(os.getenv('SUPABASE_URL'), os.getenv('SUPABASE_SERVICE_ROLE_KEY'))

small_group_involvement = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, small_group_subcategory_id)

print(small_group_involvement[0]['submission_data'])

print("Community service hours example")

community_service_subcategory_id = 'bc062d8d-6e16-4f0a-84ca-5fd9d7c10f8c'
service_hours = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, community_service_subcategory_id)

print(service_hours[0]['submission_data'])

print("Particpation points example")

gbe_subcategory_id = '0ceea111-1485-4a80-98a9-d82f3c12321c'

gbe_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, gbe_subcategory_id)

print(gbe_subcategory_submissions[0]['submission_data'])


print("Professional development categories")
job_promotion_subcategory_id = 'a3bab151-0ce1-402f-b507-7d6c3489bc8c'
credential_subcategory_id = 'efdbc642-a52d-4872-ada5-2687fc03be73'

job_promotion_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, job_promotion_subcategory_id)

print(job_promotion_subcategory_submissions[0]['submission_data'])

credential_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, credential_subcategory_id)

print(credential_subcategory_submissions[0]['submission_data'])


print("Lions Games example")

lions_games_subcategory_id = '49ccaacd-d437-4421-809a-f957c8b4baf8'

lions_games_subcategory_submissions = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory(student_id, lions_games_subcategory_id)

print(lions_games_subcategory_submissions[0]['submission_data'])
# Out:
# {'notes': 'small_group monthly check #1', 'status': 'not_involved', 'submission_type': 'small_group'}
# Community service hours example
# {'hours': 4, 'description': 'Magni culpo necessitatibus sulum timidus aeneus sit ancilla adstringo corporis.', 'organization': 'Community Garden', 'date_of_service': '2025-10-07', 'submission_type': 'community_service', 'supervisor_name': 'Trevor West', 'supervisor_contact': 'Chad.Zemlak@yahoo.com'}
# Particpation points example
# {'notes': 'gbe_participation attendance #1', 'points': 1, 'submission_type': 'participation'}
# Professional development categories
# {'description': 'Aqua certus undique paens dolorum illo capio video abbas currus adnuo patruus.', 'organization': 'ACU Apex', 'assigned_points': 50, 'promotion_title': 'Assistant → Senior Assistant', 'submission_type': 'job_promotion', 'supervisor_name': 'Eugene Kunze', 'date_of_promotion': '2025-04-14', 'supervisor_contact': 'Fred.Hirthe@gmail.com'}
# {'description': 'Synagoga provident audacia patior demergo alii ter aperiam unus desipio.', 'assigned_points': 33, 'credential_name': 'Google Analytics', 'submission_type': 'credentials', 'date_of_credential': '2025-06-14', 'granting_organization': 'Professional Certification Body'}
# Lions Games example
# {'notes': 'Lions Games points #1', 'assigned_points': 12, 'submission_type': 'lions_games'}

# %%
#Testing get_subcategories
subcategories = SubcategoryAggregator(supabase_client).get_subcategories()
print(subcategories[0:5])

#Testing get_student_submissions
student_submissions = SubcategoryAggregator(supabase_client).get_student_submissions('7630d221-e3aa-4126-a0e3-bee715160247')
print(student_submissions[0:5])

#Testing get_student_submission_by_subcategory
student_submission = SubcategoryAggregator(supabase_client).get_student_submission_by_subcategory('7630d221-e3aa-4126-a0e3-bee715160247', 'f50830fe-b820-4223-89e2-e69241b459af')
print(student_submission)
# Out:
# [{'id': '8d13f1b9-33e1-4a62-be45-488a6834112f', 'category_id': 'fe870094-f029-4cd6-9af6-e42c735c4514', 'name': 'spiritual_formation_grade', 'display_name': 'Spiritual Formation Grade', 'data_source': 'populi', 'weight': 1.0, 'created_at': '2025-07-31T19:50:25.698898+00:00'}, {'id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'category_id': 'fe870094-f029-4cd6-9af6-e42c735c4514', 'name': 'chapel_participation', 'display_name': 'Chapel Team Participation', 'data_source': 'student_input', 'weight': 1.0, 'created_at': '2025-07-31T19:50:25.698898+00:00'}, {'id': 'a32c3898-dbf1-4a92-a5db-811dfb6fcd0f', 'category_id': 'fe870094-f029-4cd6-9af6-e42c735c4514', 'name': 'small_group_involvement', 'display_name': 'Small Group Involvement', 'data_source': 'student_input', 'weight': 1.0, 'created_at': '2025-07-31T19:50:25.698898+00:00'}, {'id': 'e0bd5604-0692-42fe-8b4b-7ea2d339abc7', 'category_id': 'fe870094-f029-4cd6-9af6-e42c735c4514', 'name': 'dream_team_involvement', 'display_name': 'Dream Team Involvement', 'data_source': 'student_input', 'weight': 1.0, 'created_at': '2025-07-31T19:50:25.698898+00:00'}, {'id': 'bc062d8d-6e16-4f0a-84ca-5fd9d7c10f8c', 'category_id': 'fe870094-f029-4cd6-9af6-e42c735c4514', 'name': 'community_service_hours', 'display_name': 'Community Service Hours', 'data_source': 'student_input', 'weight': 1.0, 'created_at': '2025-07-31T19:50:25.698898+00:00'}]
# [{'id': '4effc6ca-1ed3-42a1-820e-ab6ac5584067', 'event_id': '06e57083-bbeb-4dfc-ad64-eefeec1a1661', 'student_id': '7630d221-e3aa-4126-a0e3-bee715160247', 'submitted_by': '7630d221-e3aa-4126-a0e3-bee715160247', 'submission_data': {'notes': 'chapel_participation #1', 'rating': 5, 'submission_type': 'chapel_participation'}, 'submitted_at': '2025-03-16T13:49:02.493+00:00', 'subcategory_id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'needs_approval': False, 'approval_status': 'pending', 'approved_by': None, 'points_granted': None}, {'id': '67e2f400-8149-4fb3-b6a5-31ec23f0f85b', 'event_id': 'e28ac324-1128-4141-ad48-507f347379be', 'student_id': '7630d221-e3aa-4126-a0e3-bee715160247', 'submitted_by': '7630d221-e3aa-4126-a0e3-bee715160247', 'submission_data': {'notes': 'chapel_participation #2', 'rating': 4.4, 'submission_type': 'chapel_participation'}, 'submitted_at': '2025-05-11T10:31:34.117+00:00', 'subcategory_id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'needs_approval': False, 'approval_status': 'pending', 'approved_by': None, 'points_granted': None}, {'id': '69cd9ec0-6364-4f1f-a569-b61735f39d24', 'event_id': 'ddac413d-2c01-47c7-9cfa-089249130cc4', 'student_id': '7630d221-e3aa-4126-a0e3-bee715160247', 'submitted_by': '7630d221-e3aa-4126-a0e3-bee715160247', 'submission_data': {'notes': 'chapel_participation #3', 'rating': 3.7, 'submission_type': 'chapel_participation'}, 'submitted_at': '2025-09-10T04:42:59.141+00:00', 'subcategory_id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'needs_approval': False, 'approval_status': 'pending', 'approved_by': None, 'points_granted': None}, {'id': 'd74355d2-c823-4357-9203-84ddee13be58', 'event_id': '44884484-343b-4684-a9fa-9decd2e874e9', 'student_id': '7630d221-e3aa-4126-a0e3-bee715160247', 'submitted_by': '7630d221-e3aa-4126-a0e3-bee715160247', 'submission_data': {'notes': 'chapel_participation #4', 'rating': 4.2, 'submission_type': 'chapel_participation'}, 'submitted_at': '2025-02-12T13:40:15.267+00:00', 'subcategory_id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'needs_approval': False, 'approval_status': 'pending', 'approved_by': None, 'points_granted': None}, {'id': 'cd6718be-5470-458b-97ca-0aaf32660c0a', 'event_id': '7cb9f4f8-478f-4d55-b5b3-c3e29ab68e24', 'student_id': '7630d221-e3aa-4126-a0e3-bee715160247', 'submitted_by': '7630d221-e3aa-4126-a0e3-bee715160247', 'submission_data': {'notes': 'chapel_participation #5', 'rating': 3.6, 'submission_type': 'chapel_participation'}, 'submitted_at': '2025-08-27T18:23:00.543+00:00', 'subcategory_id': '865e0e15-c14d-4b23-abd2-5f1b6ccf5dbc', 'needs_approval': False, 'approval_status': 'pending', 'approved_by': None, 'points_granted': None}]
# []
